# %%
#importing all the library for data manuplation 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the csv file by giving the path

# %%
df = pd.read_csv("C:/Users/lalit/Downloads/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# group the dataset by cp(chest_Pain) and took the median of it

# %%
df_cp = df.groupby(by='cp').median().reset_index()

# %%
df_cp
# Out:
#    cp   age  sex  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   0  57.0  1.0     130.0  248.0  0.0      0.0    143.0    1.0      1.2
# 1   1  52.0  1.0     128.0  238.0  0.0      1.0    163.5    0.0      0.0
# 2   2  53.0  1.0     130.0  233.0  0.0      1.0    158.0    0.0      0.5
# 3   3  59.0  1.0     140.0  234.0  0.0      0.0    159.0    0.0      1.2
#
#    slope   ca  thal  target
# 0    1.0  1.0   3.0     0.0
# 1    2.0  0.0   2.0     1.0
# 2    2.0  0.0   2.0     1.0
# 3    1.0  0.0   2.0     1.0

# %%
# draw a bar chart using pandas giving x_axis = cp and y_axis = chol (relation between cp and chol)

# %%
df_cp.plot.bar(x='cp',y='chol')
# Out:
# <Axes: xlabel='cp'>

# %%
# if we do not mention y axis then it will take all the possible columns

# %%
df_cp.plot.bar(x='cp')
# Out:
# <Axes: xlabel='cp'>

# %%
# now if we see the relation between age and chol first we took the group of ages

# %%
df_age  = df.groupby('age').median().reset_index()

# %%
df_age.head()
# Out:
#    age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   29  1.0  1.0     130.0  204.0  0.0      0.0    202.0    0.0     0.00
# 1   34  0.5  2.0     118.0  196.0  0.0      0.5    183.0    0.0     0.35
# 2   35  1.0  0.0     124.0  195.0  0.0      1.0    165.0    0.5     0.70
# 3   37  0.5  2.0     125.0  232.5  0.0      1.0    178.5    0.0     1.75
# 4   38  1.0  2.0     138.0  175.0  0.0      1.0    173.0    0.0     0.00
#
#    slope   ca  thal  target
# 0    2.0  0.0   2.0     1.0
# 1    2.0  0.0   2.0     1.0
# 2    2.0  0.0   2.5     0.5
# 3    1.0  0.0   2.0     1.0
# 4    2.0  4.0   2.0     1.0

# %%
df['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
df_age.plot.bar(x='age',y='chol')
# Out:
# <Axes: xlabel='age'>

# %%
# now if we see  relation between age and chol on line chart instead of bar chart

# %%
df_age.plot.line('age','chol',)
# Out:
# <Axes: xlabel='age'>

# %%
# now if we wanna relation of age with respect to chol and trestbps simantaneously on a line chart

# %%
df_age.plot.line('age',['chol','trestbps','thalach'])
# Out:
# <Axes: xlabel='age'>

# %%
# ploting a histogram to take a grasp look how many people lies between particular age period and when we define bins it will 
plot same amount of bins
# Out:
#   Cell In[85], line 2
#     plot same amount of bins
#          ^
# SyntaxError: invalid syntax

# %%
df.age.plot.hist(bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# drawing a box plot using pandas it shows basicllay outlier, mean, and, quartile

# %%
df[['chol','thalach']].plot.box()
# Out:
# <Axes: >

# %%
df[['chol','thalach']].describe()
# Out:
#              chol     thalach
# count  303.000000  303.000000
# mean   246.264026  149.646865
# std     51.830751   22.905161
# min    126.000000   71.000000
# 25%    211.000000  133.500000
# 50%    240.000000  153.000000
# 75%    274.500000  166.000000
# max    564.000000  202.000000

# %%
# for boxplot we use seaborn library for a better visulation

# %%
sns.boxplot(x ='cp',y='thalach',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='thalach'>

# %%
sns.boxplot(x='cp',y='chol',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='chol'>

# %%
# importing a new dataset to work on 2d visulation

# %%
df1= pd.read_csv("C:\Users/lalit/Downloads/meteorite-landings.csv")
# Out:
#   Cell In[245], line 1
#     df1= pd.read_csv("C:\Users/lalit/Downloads/meteorite-landings.csv")
#                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df1
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass         45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45428 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
df1.isnull().sum()
# Out:
# name              0
# id                0
# nametype          0
# recclass          0
# mass            131
# fall              0
# year            288
# reclat         7315
# reclong        7315
# GeoLocation    7315
# dtype: int64

# %%
df1.dropna()
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
import numpy as np
df3 = pd.DataFrame(np.random.normal(size=(6,6)),columns=[x for x in 'abcdef'])

# %%
#according to their value in the dataset filling the different color

# %%
df3
# Out:
#           a         b         c         d         e         f
# 0 -0.231279 -0.786488 -0.593246  0.792625  0.301497 -0.965918
# 1  0.559013  1.224968  0.470206 -0.964707  0.281420  0.102650
# 2  0.015017 -2.002319  0.696896 -0.374120  1.555357  0.028859
# 3 -1.508112 -0.581833  0.049227  1.837838 -0.925136 -0.721077
# 4 -0.410678 -0.334956 -0.004585 -0.775187  1.422569  0.290317
# 5 -0.067033 -1.205875  0.205701 -1.139789 -0.779459  1.051449

# %%
df3.style.background_gradient(cmap = 'magma')
# Out:
# <style type="text/css">
# #T_ca6a2_row0_col0, #T_ca6a2_row5_col2 {
#   background-color: #e44f64;
#   color: #f1f1f1;
# }
# #T_ca6a2_row0_col1 {
#   background-color: #832681;
#   color: #f1f1f1;
# }
# #T_ca6a2_row0_col2, #T_ca6a2_row0_col5, #T_ca6a2_row2_col1, #T_ca6a2_row3_col0, #T_ca6a2_row3_col4, #T_ca6a2_row5_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_ca6a2_row0_col3 {
#   background-color: #ed5a5f;
#   color: #f1f1f1;
# }
# #T_ca6a2_row0_col4, #T_ca6a2_row2_col5 {
#   background-color: #b3367a;
#   color: #f1f1f1;
# }
# #T_ca6a2_row1_col0, #T_ca6a2_row1_col1, #T_ca6a2_row2_col2, #T_ca6a2_row2_col4, #T_ca6a2_row3_col3, #T_ca6a2_row5_col5 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_ca6a2_row1_col2 {
#   background-color: #feac76;
#   color: #000000;
# }
# #T_ca6a2_row1_col3, #T_ca6a2_row5_col4 {
#   background-color: #090720;
#   color: #f1f1f1;
# }
# #T_ca6a2_row1_col4 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# ...

# %%
#visulazing nd data

# %%
df3.corr()
# Out:
#           a         b         c         d         e         f
# a  1.000000  0.249945  0.359541 -0.810436  0.411080  0.447965
# b  0.249945  1.000000 -0.050877 -0.138455 -0.153454 -0.063802
# c  0.359541 -0.050877  1.000000 -0.473731  0.244197  0.525197
# d -0.810436 -0.138455 -0.473731  1.000000 -0.378827 -0.852555
# e  0.411080 -0.153454  0.244197 -0.378827  1.000000  0.028617
# f  0.447965 -0.063802  0.525197 -0.852555  0.028617  1.000000

# %%
# using seaborn library to fill the correaltion table
import seaborn as sns

# %%
ax = sns.heatmap(df3.corr(),annot = True,fmt='0.2f',square =True)

# %%
# basic manipulation of the data 
# indexing
# slicingcs
# ordering
# filtering
# replacing
# cleaning

# %%
df = pd.read_csv("C:/Users/lalit/Downloads/P87-Section-4-Basic-Data-Manipulations-Resources/P87-S4-Basic-Data-Manipulations-Resources/AB_NYC_2019.csv")

# %%
import pandas as pd

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1 = df.set_index('id')
df1.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df1.host_name[2539]
# Out:
# 'John'

# %%
df1.name[2595]
# Out:
# 'Skylit Midtown Castle'

# %%
df2 = df1.groupby('room_type').mean()
# Out:
# C:\Users\lalit\AppData\Local\Temp\ipykernel_2296\3503705336.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df1.groupby('room_type').mean()

# %%
df2
# Out:
#                       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  6.175593e+07  40.728649 -73.960696  211.794246
# Private room     7.247514e+07  40.729208 -73.942924   89.780973
# Shared room      1.026241e+08  40.730514 -73.943343   70.127586
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        8.506907          22.842418           1.306578
# Private room           5.377900          24.112962           1.445209
# Shared room            6.475000          16.600000           1.471726
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       10.698335        111.920304
# Private room                           3.227717        111.203933
# Shared room                            4.662931        162.000862

# %%
df2.reset_index()
# Out:
#          room_type       host_id   latitude  longitude       price  \
# 0  Entire home/apt  6.175593e+07  40.728649 -73.960696  211.794246
# 1     Private room  7.247514e+07  40.729208 -73.942924   89.780973
# 2      Shared room  1.026241e+08  40.730514 -73.943343   70.127586
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0        8.506907          22.842418           1.306578
# 1        5.377900          24.112962           1.445209
# 2        6.475000          16.600000           1.471726
#
#    calculated_host_listings_count  availability_365
# 0                       10.698335        111.920304
# 1                        3.227717        111.203933
# 2                        4.662931        162.000862

# %%
# sorting

# %%
df2.sort_index(ascending =False)
# Out:
#                       host_id   latitude  longitude       price  \
# room_type
# Shared room      1.026241e+08  40.730514 -73.943343   70.127586
# Private room     7.247514e+07  40.729208 -73.942924   89.780973
# Entire home/apt  6.175593e+07  40.728649 -73.960696  211.794246
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Shared room            6.475000          16.600000           1.471726
# Private room           5.377900          24.112962           1.445209
# Entire home/apt        8.506907          22.842418           1.306578
#
#                  calculated_host_listings_count  availability_365
# room_type
# Shared room                            4.662931        162.000862
# Private room                           3.227717        111.203933
# Entire home/apt                       10.698335        111.920304

# %%
df.sort_values('host_name')
# Out:
#              id                                               name    host_id  \
# 11137   8622301                    Astoria Full Basement Apartment   45354224
# 10315   7899658                                  MANHATTAN LIVING!   40605120
# 5330    3848324                       West Village apt - 2 Bedroom   11495251
# 35170  27903031                Prewar Gem in Middle of Everything!    7580102
# 15242  12190880        Upper West Side One Bedroom on Central Park   65527002
# ...         ...                                                ...        ...
# 28042  21901156  Best Deal! Lovely place in Manhattan! Time Squ...  159156636
# 28274  21990808                 ***SLEEPING IN THE GOLDEN PLACE***  159156636
# 30570  23660605    Private Bedroom w/ Balcony view of Central Park  177146433
# 32193  25180572                     Beautiful Cozy Studio Apt. UWS  119609345
# 38992  30468335            LARGE Prospect Lefferts Gardens Bedroom  228750026
#
# ...

# %%
df.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# ranking( first we have to sort the order of the column then use rank function and add the column in sorted dataframe )

# %%
dfp=df.sort_values('price',ascending =False)

# %%
dfp
# Out:
#              id                                               name    host_id  \
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29238  22436899                                1-BR Lincoln Center   72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# ...         ...                                                ...        ...
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
#
# ...

# %%
dfp[['id','host_name','price']].head()
# Out:
#              id host_name  price
# 9151    7003697  Kathrine  10000
# 17692  13894339      Erin  10000
# 29238  22436899    Jelena  10000
# 40433  31340283      Matt   9999
# 12342   9528920       Amy   9999

# %%
# we can use different method for ranking like min max and average

# %%
dfp['price_rank']=dfp.price.rank(method = 'average',ascending =False)

# %%
dfp[['id','host_name','price','price_rank']].head()
# Out:
#              id host_name  price  price_rank
# 9151    7003697  Kathrine  10000         2.0
# 17692  13894339      Erin  10000         2.0
# 29238  22436899    Jelena  10000         2.0
# 40433  31340283      Matt   9999         5.0
# 12342   9528920       Amy   9999         5.0

# %%
dfk = df.sort_values('price',ascending =False)

# %%
dfk[['id','host_name','price']].head()
# Out:
#              id host_name  price
# 9151    7003697  Kathrine  10000
# 17692  13894339      Erin  10000
# 29238  22436899    Jelena  10000
# 40433  31340283      Matt   9999
# 12342   9528920       Amy   9999

# %%
dfk['price_rank'] = dfk.price.rank(method='min',ascending =False)

# %%
dfk[['id','host_name','price','price_rank']].head()
# Out:
#              id host_name  price  price_rank
# 9151    7003697  Kathrine  10000         1.0
# 17692  13894339      Erin  10000         1.0
# 29238  22436899    Jelena  10000         1.0
# 40433  31340283      Matt   9999         4.0
# 12342   9528920       Amy   9999         4.0

# %%
df_sorted=df.sort_values('price',ascending =False)

# %%
df_sorted.head()
# Out:
#              id                                               name   host_id  \
# 9151    7003697                Furnished room in Astoria apartment  20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                                1-BR Lincoln Center  72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 40433      Matt           Manhattan  Lower East Side  40.71980  -73.98566
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
#
# ...

# %%
df_sorted[['host_name','room_type','price']].head()
# Out:
#       host_name        room_type  price
# 9151   Kathrine     Private room  10000
# 17692      Erin  Entire home/apt  10000
# 29238    Jelena  Entire home/apt  10000
# 40433      Matt  Entire home/apt   9999
# 12342       Amy     Private room   9999

# %%
df_sorted['price_rank']=df_sorted.price.rank(method ='max',ascending=False)

# %%
df_sorted[['host_name','room_type','price','price_rank']].head()
# Out:
#       host_name        room_type  price  price_rank
# 9151   Kathrine     Private room  10000         3.0
# 17692      Erin  Entire home/apt  10000         3.0
# 29238    Jelena  Entire home/apt  10000         3.0
# 40433      Matt  Entire home/apt   9999         6.0
# 12342       Amy     Private room   9999         6.0

# %%
# filtering

# %%
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
 quick_and_cheap= df[(df.price<100) & (df.minimum_nights<3)]

# %%
 quick_and_cheap.head()
# Out:
#       id                                              name  host_id  \
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 11  5441                   Central Manhattan/near Broadway     7989
# 13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 3   LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 7      Shunichi           Manhattan   Hell's Kitchen  40.76489  -73.98493
# 8     MaryEllen           Manhattan  Upper West Side  40.80178  -73.96723
# 11         Kate           Manhattan   Hell's Kitchen  40.76076  -73.98867
# 13      Claudio           Manhattan  Upper West Side  40.79826  -73.96113
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
review_consistant=df[(df.number_of_reviews>50) &(df.reviews_per_month>3)]

# %%
review_consistant.head()
# Out:
#        id                                             name  host_id  \
# 3    3831                  Cozy Entire Floor of Brownstone     4869
# 7    5178                 Large Furnished Room Near B'way      8967
# 18   7726  Hip Historic Brownstone Apartment with Backyard    20950
# 67  16580              Sunny, Modern room in East Village!    64442
# 91  20734              Spacious Prospect Heights Apartment    78460
#
#            host_name neighbourhood_group     neighbourhood  latitude  \
# 3        LisaRoxanne            Brooklyn      Clinton Hill  40.68514
# 7           Shunichi           Manhattan    Hell's Kitchen  40.76489
# 18  Adam And Charity            Brooklyn     Crown Heights  40.67592
# 67              Reka           Manhattan      East Village  40.72649
# 91    Sean & Lynette            Brooklyn  Prospect Heights  40.68233
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
#locking and ilocking(both do subsetting of a dataframe loc works on column name and iloc works on column no)

# %%
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
df.loc[2:3.,'name':'host_name']
# Out:
#                                   name  host_id    host_name
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3      Cozy Entire Floor of Brownstone     4869  LisaRoxanne

# %%
df.iloc[2:4,1:4]
# Out:
#                                   name  host_id    host_name
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3      Cozy Entire Floor of Brownstone     4869  LisaRoxanne

# %%
df.replace('Elisabeth','LisaRoxanne').head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2  LisaRoxanne           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df.price,log=True,bins=30)
# Out:
# (array([4.5918e+04, 2.2790e+03, 4.0000e+02, 1.2100e+02, 4.5000e+01,
#         2.2000e+01, 3.1000e+01, 1.7000e+01, 9.0000e+00, 1.0000e+01,
#         4.0000e+00, 4.0000e+00, 7.0000e+00, 2.0000e+00, 0.0000e+00,
#         8.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00, 4.0000e+00,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+00]),
#  array([    0.        ,   333.33333333,   666.66666667,  1000.        ,
#          1333.33333333,  1666.66666667,  2000.        ,  2333.33333333,
#          2666.66666667,  3000.        ,  3333.33333333,  3666.66666667,
#          4000.        ,  4333.33333333,  4666.66666667,  5000.        ,
#          5333.33333333,  5666.66666667,  6000.        ,  6333.33333333,
#          6666.66666667,  7000.        ,  7333.33333333,  7666.66666667,
#          8000.        ,  8333.33333333,  8666.66666667,  9000.        ,
#          9333.33333333,  9666.66666667, 10000.        ]),
# ...

# %%
#replacing and adding data

# %%
# modifying the column type

# %%
df =pd.read_csv("C:/Users/lalit/Downloads/P87-Section-4-Basic-Data-Manipulations-Resources/P87-S4-Basic-Data-Manipulations-Resources/astronauts.csv")

# %%
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
df.dtypes
# Out:
# Name                    object
# Year                   float64
# Group                  float64
# Status                  object
# Birth Date              object
# Birth Place             object
# Gender                  object
# Alma Mater              object
# Undergraduate Major     object
# Graduate Major          object
# Military Rank           object
# Military Branch         object
# Space Flights            int64
# Space Flight (hr)        int64
# Space Walks              int64
# Space Walks (hr)       float64
# Missions                object
# Death Date              object
# Death Mission           object
# dtype: object

# %%
birthdate = pd.to_datetime(df['Birth Date'])

# %%
df['birthdate'] = birthdate

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
# droping and adding a column

# %%
df.drop('birthdate',axis=True)
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
df.append({'Name':'sourav','Year':'2010',' Status':'active'},ignore_index=True)
# Out:
# C:\Users\lalit\AppData\Local\Temp\ipykernel_2296\1122042878.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'Name':'sourav','Year':'2010',' Status':'active'},ignore_index=True)
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
# ...

# %%
df=df.dropna()

# %%
df['year'] = df['Year'].astype(int)
# Out:
# C:\Users\lalit\AppData\Local\Temp\ipykernel_2296\4120280643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['Year'].astype(int)

# %%
df['year'].dtype
# Out:
# dtype('int32')

# %%
# pandas has three datastructure
# 1 series
# 2 dataframe
# 3 panel

# %%
# let work on series

# %%
pd.Series([4,5,6,8])
# Out:
# 0    4
# 1    5
# 2    6
# 3    8
# dtype: int64

# %%
# series like dictionary(key and value)

# %%
mask = pd.Series({'sourav':'joon','interest':'nothing','goal':'peace'})

# %%
pd.Series(mask)
# Out:
# sourav         joon
# interest    nothing
# goal          peace
# dtype: object

# %%
# section 5  grouping
import pandas as pd

# %%
df = pd.read_csv("C:/Users/lalit/Downloads/P87-S5-Grouping-Resources/train.csv",parse_dates=['Date'],low_memory=False)

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %%
dfg = df.groupby('Store').mean()
# Out:
# C:\Users\lalit\AppData\Local\Temp\ipykernel_16348\2526920004.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfg = df.groupby('Store').mean()

# %%
avg_sales=dfg.reset_index()

# %%
import matplotlib.pyplot as plt

# %%
avg_sales.plot.scatter('Store','Sales',title='avg_sales_per-store',s=3)
# Out:
# <Axes: title={'center': 'avg_sales_per-store'}, xlabel='Store', ylabel='Sales'>

# %%
df.sort_values('Sales',ascending=False)
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 44393      909          1 2015-06-22  41551       1721     1      0
# 132946     262          5 2015-04-03  38722       5132     1      1
# 101726     262          5 2015-05-01  38484       5458     1      1
# 87231      262          4 2015-05-14  38367       5192     1      0
# 424086      57          1 2014-06-16  38037       1970     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 298723     762          7 2014-10-26      0          0     0      0
# 298722     761          7 2014-10-26      0          0     0      0
# 298721     760          7 2014-10-26      0          0     0      0
# 298720     759          7 2014-10-26      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 44393              0              0
# 132946             b              0
# 101726             a              0
# ...

# %%
# grouping

# %%
bins = [0,2000,4000,6000,10000,50000]

# %%
cuts = pd.cut(df.Sales,bins,include_lowest=True)
df['sales_group'] =cuts
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday         sales_group
# 0              1    (4000.0, 6000.0]
# 1              1   (6000.0, 10000.0]
# 2              1   (6000.0, 10000.0]
# 3              1  (10000.0, 50000.0]
# 4              1    (4000.0, 6000.0]

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.groupby(['Store','sales_group']).DayOfWeek.value_counts().unstack(fill_value=0)
# Out:
# DayOfWeek                  1   2   3   4   5    6    7
# Store sales_group
# 1     (-0.001, 2000.0]     6   1   3  11   6    0  134
#       (2000.0, 4000.0]    28  42  42  43  28   13    0
#       (4000.0, 6000.0]    70  80  83  72  91  109    0
#       (6000.0, 10000.0]   30  12   7   9  10   12    0
# 2     (-0.001, 2000.0]     6   1   3   8   6    1  134
# ...                       ..  ..  ..  ..  ..  ...  ...
# 1115  (-0.001, 2000.0]     6   1   3  11   6    0  134
#       (2000.0, 4000.0]    15  17  15   9   0    0    0
#       (4000.0, 6000.0]    34  54  65  64  61   36    0
#       (6000.0, 10000.0]   67  61  51  49  61   96    0
#       (10000.0, 50000.0]  12   2   1   2   7    2    0
#
# [5199 rows x 7 columns]

# %%
df.groupby(['Store','sales_group','DayOfWeek']).Sales.value_counts()
# Out:
# Store  sales_group         DayOfWeek  Sales
# 1      (-0.001, 2000.0]    1          0         6
#                            2          0         1
#                            3          0         3
#                            4          0        11
#                            5          0         6
#                                                ..
# 1115   (10000.0, 50000.0]  5          10636     1
#                                       11435     1
#                                       11673     1
#                            6          10444     1
#                                       10898     1
# Name: Sales, Length: 836808, dtype: int64

# %%
# different aggertion for different columns

# %%
df.groupby(['Store','DayOfWeek']).agg({'Sales':'mean','Customers':'count'})
# Out:
#                        Sales  Customers
# Store DayOfWeek
# 1     1          4946.119403        134
#       2          4650.918519        135
#       3          4454.474074        135
#       4          4094.607407        135
#       5          4516.414815        135
# ...                      ...        ...
# 1115  3          5666.155556        135
#       4          5396.607407        135
#       5          6208.881481        135
#       6          6773.388060        134
#       7             0.000000        134
#
# [7805 rows x 2 columns]

# %%
df2=df.groupby(['Store','DayOfWeek']).agg({'Sales':['mean','max','min'],'Customers':'count'}).head()

# %%
df2.head()
# Out:
#                        Sales           Customers
#                         mean   max min     count
# Store DayOfWeek
# 1     1          4946.119403  9528   0       134
#       2          4650.918519  7959   0       135
#       3          4454.474074  7821   0       135
#       4          4094.607407  7785   0       135
#       5          4516.414815  8414   0       135

# %%
df2.columns = ['Sales',"Salesmax",'sales_min','counts']

# %%
df2.head()
# Out:
#                        Sales  Salesmax  sales_min  counts
# Store DayOfWeek
# 1     1          4946.119403      9528          0     134
#       2          4650.918519      7959          0     135
#       3          4454.474074      7821          0     135
#       4          4094.607407      7785          0     135
#       5          4516.414815      8414          0     135

# %%
# solving the question of till grouping section  5

# %%
df = pd.read_csv("C:/Users/lalit/Downloads/P87-S5-Grouping-Resources/Section 5 - Extra Example Resources/vgsales.csv")

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_action=df[df.Genre=='Action'].sort_values('Global_Sales',ascending=False)

# %%
df_action.Name.head()
# Out:
# 16               Grand Theft Auto V
# 17    Grand Theft Auto: San Andreas
# 23               Grand Theft Auto V
# 24      Grand Theft Auto: Vice City
# 38             Grand Theft Auto III
# Name: Name, dtype: object

# %%
#1. Which genre has the highest average global sales averaged over all games
#2. Which top 5 games are responsible for the biggest profit in that genre?
#3. For each platform and year, what is the highest performing game?
#4. For each Genre, what is the mean and standard deviation for game sales in EU? 
#5. Bonus advanced follow up - can you answer if mean and std is a good representation of the data? (Hint code provided)

# %%
# Question 1
df_genere=df.groupby('Genre').sum('Global_Sales')

# %%
df_genere.sort_values('Global_Sales',ascending=False)
# Out:
#                   Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        26441383  6531731.0    877.83    525.00    159.95       187.38
# Sports        17419112  4620621.0    683.35    376.85    135.37       134.97
# Shooter        9653872  2571588.0    582.60    313.27     38.28       102.69
# Role-Playing  12032228  2952379.0    327.28    188.06    352.31        59.61
# Platform       6137545  1755347.0    447.05    201.63    130.77        51.59
# Misc          14889052  3432412.0    410.24    215.98    107.76        75.32
# Racing         9943933  2457934.0    359.42    238.39     56.69        77.27
# Fighting       6484242  1675871.0    223.59    101.32     87.35        36.68
# Simulation     7478816  1707589.0    183.31    113.38     63.70        31.52
# Puzzle         5603136  1144994.0    123.78     50.78     57.31        12.55
# Adventure     14831165  2562375.0    105.80     64.13     52.07        16.81
# ...

# %%
# Question 2 top 5 games responsible for the biggest profit

# %%
df[df.Genre=='Platform'].sort_values("Global_Sales",ascending=False).Name.head(5)
# Out:
# 1             Super Mario Bros.
# 6         New Super Mario Bros.
# 8     New Super Mario Bros. Wii
# 18            Super Mario World
# 21             Super Mario Land
# Name: Name, dtype: object

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.groupby(['Genre','Platform','Year']).Global_Sales.sum().reset_index()
# Out:
#          Genre Platform    Year  Global_Sales
# 0       Action     2600  1980.0          0.34
# 1       Action     2600  1981.0         14.84
# 2       Action     2600  1982.0          6.52
# 3       Action     2600  1983.0          2.86
# 4       Action     2600  1987.0          1.12
# ...        ...      ...     ...           ...
# 1799  Strategy       XB  2005.0          0.37
# 1800  Strategy       XB  2006.0          0.05
# 1801  Strategy     XOne  2013.0          0.16
# 1802  Strategy     XOne  2015.0          0.20
# 1803  Strategy     XOne  2016.0          0.02
#
# [1804 rows x 4 columns]

# %%
stats
# Out:
#            Genre    MeanEU     StdEU
# 0         Action  0.158323  0.407424
# 1      Adventure  0.049868  0.176454
# 2       Fighting  0.119481  0.253013
# 3           Misc  0.124198  0.446592
# 4       Platform  0.227573  0.588545
# 5         Puzzle  0.087251  0.318550
# 6         Racing  0.190865  0.581181
# 7   Role-Playing  0.126384  0.488864
# 8        Shooter  0.239137  0.549189
# 9     Simulation  0.130773  0.514097
# 10        Sports  0.160635  0.776772
# 11      Strategy  0.066579  0.192594

# %%
df.groupby('Genre').agg(MeanEu=( 'EU_Sales','mean'),StdEU=('EU_Sales','std')).reset_index()
# Out:
#            Genre    MeanEu     StdEU
# 0         Action  0.158323  0.407424
# 1      Adventure  0.049868  0.176454
# 2       Fighting  0.119481  0.253013
# 3           Misc  0.124198  0.446592
# 4       Platform  0.227573  0.588545
# 5         Puzzle  0.087251  0.318550
# 6         Racing  0.190865  0.581181
# 7   Role-Playing  0.126384  0.488864
# 8        Shooter  0.239137  0.549189
# 9     Simulation  0.130773  0.514097
# 10        Sports  0.160635  0.776772
# 11      Strategy  0.066579  0.192594

# %%
# section 6( merging)
import pandas as pd

# %%
grade1=pd.read_csv("C:/Users/lalit/Downloads/P87-Section-6-Merging-Resources/P87-S6-Merging-Resources/grades1.csv")
grade2 =pd.read_csv("C:/Users/lalit/Downloads/P87-Section-6-Merging-Resources/P87-S6-Merging-Resources/grades2.csv")
teacher=pd.read_csv("C:/Users/lalit/Downloads/P87-Section-6-Merging-Resources/P87-S6-Merging-Resources/teachers.csv")
students=pd.read_csv("C:/Users/lalit/Downloads/P87-Section-6-Merging-Resources/P87-S6-Merging-Resources/students.csv")
contact=pd.read_csv("C:/Users/lalit/Downloads/P87-Section-6-Merging-Resources/P87-S6-Merging-Resources/contact.csv")

# %%
#first we do the vertical merging that is basically done by the concat function

# %%
students.head(2)
# Out:
#       id firstname lastname
# 0  34292    Joshua    Davis
# 1  34293     Karen   Flores

# %%
teacher.head(2)
# Out:
#     course        teacher
# 0  PHYS101   Wayne Walker
# 1  CHEM101  Albert Taylor

# %%
contact.head(2)
# Out:
#    student_id parent_contact           phone
# 0       34292   Samuel Davis  (356) 849-0352
# 1       34293   Laura Flores  (477) 325-7117

# %%
grade1.head(2)
# Out:
#    student_id   course grade
# 0       34292  ENGL101     A
# 1       34293  ENGL101     A

# %%
grade2.head(2)
# Out:
#    student_id   course grade
# 0       34302  DRAM101     F
# 1       34303  DRAM101     D

# %%
grade1['semester']=1
grade2['semester']=2

# %%
grades=pd.concat([grade1,grade2])

# %%
grades
# Out:
#     student_id   course grade  semester
# 0        34292  ENGL101     A         1
# 1        34293  ENGL101     A         1
# 2        34294  ENGL101     C         1
# 3        34295  ENGL101     C         1
# 4        34296  ENGL101     C         1
# ..         ...      ...   ...       ...
# 60       34312  DESN101     E         2
# 61       34313  DESN101     D         2
# 62       34314  DESN101     A         2
# 63       34315  DESN101     A         2
# 64       34316  DESN101     A         2
#
# [190 rows x 4 columns]

# %%
# Horizontal merging that is basically done by the merging function

# %%
students_grades= pd.merge(students,grades,left_on='id',right_on='student_id')

# %%
students_grades
# Out:
#         id firstname  lastname  student_id   course grade  semester
# 0    34292    Joshua     Davis       34292  ENGL101     A         1
# 1    34292    Joshua     Davis       34292  MATH101     A         1
# 2    34292    Joshua     Davis       34292  PHYS101     D         1
# 3    34292    Joshua     Davis       34292  MATH102     F         1
# 4    34292    Joshua     Davis       34292  COMP101     A         1
# ..     ...       ...       ...         ...      ...   ...       ...
# 185  34316   Stephen  Martinez       34316  ARTT101     A         1
# 186  34316   Stephen  Martinez       34316  DESN101     A         1
# 187  34316   Stephen  Martinez       34316  DRAM101     F         2
# 188  34316   Stephen  Martinez       34316  ARTT101     A         2
# 189  34316   Stephen  Martinez       34316  DESN101     A         2
#
# [190 rows x 7 columns]

# %%
#check wheather if we do dont drop tha data

# %%
print(students_grades.shape,grades.shape)
# Out:
# (190, 7) (190, 4)

# %%
contact=contact.rename({'student_id':'id'},axis=1)

# %%
student_full=pd.merge(students_grades,contact,on='id')

# %%
student_full
# Out:
#         id firstname  lastname  student_id   course grade  semester  \
# 0    34292    Joshua     Davis       34292  ENGL101     A         1
# 1    34292    Joshua     Davis       34292  MATH101     A         1
# 2    34292    Joshua     Davis       34292  PHYS101     D         1
# 3    34292    Joshua     Davis       34292  MATH102     F         1
# 4    34292    Joshua     Davis       34292  COMP101     A         1
# ..     ...       ...       ...         ...      ...   ...       ...
# 185  34316   Stephen  Martinez       34316  ARTT101     A         1
# 186  34316   Stephen  Martinez       34316  DESN101     A         1
# 187  34316   Stephen  Martinez       34316  DRAM101     F         2
# 188  34316   Stephen  Martinez       34316  ARTT101     A         2
# 189  34316   Stephen  Martinez       34316  DESN101     A         2
#
#      parent_contact           phone
# 0      Samuel Davis  (356) 849-0352
# 1      Samuel Davis  (356) 849-0352
# 2      Samuel Davis  (356) 849-0352
# ...

# %%
students_full=pd.merge(student_full,teacher,on='course')

# %%
students_full.reset_index(drop=True)
# Out:
#         id firstname  lastname  student_id   course grade  semester  \
# 0    34292    Joshua     Davis       34292  ENGL101     A         1
# 1    34293     Karen    Flores       34293  ENGL101     A         1
# 2    34294     Julia    Walker       34294  ENGL101     C         1
# 3    34295   Cynthia  Robinson       34295  ENGL101     C         1
# 4    34296    Bonnie      Hall       34296  ENGL101     C         1
# ..     ...       ...       ...         ...      ...   ...       ...
# 185  34314   Melissa     Price       34314  ARTT101     C         2
# 186  34315   Russell      Reed       34315  ARTT101     D         1
# 187  34315   Russell      Reed       34315  ARTT101     D         2
# 188  34316   Stephen  Martinez       34316  ARTT101     A         1
# 189  34316   Stephen  Martinez       34316  ARTT101     A         2
#
#      parent_contact           phone       teacher
# 0      Samuel Davis  (356) 849-0352  Ernest Green
# ...

# %%
status=[]
for i in students_full.columns:
    if grade=='F':
        status.append(fail)
    else:
        print(Pass)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 status=[]
#       2 for i in students_full.grade:
# ----> 3     if grade=='F':
#       4         status.append(fail)
#       5     else:
#
# NameError: name 'grade' is not defined

# %%
#merging

# %%
df1=pd.DataFrame({'A':['x','y','z'],'B':[2,3,4]})
df2=pd.DataFrame({'A':['u','v','x'],'C':[5,6,7]})

# %%
df1
# Out:
#    A  B
# 0  x  2
# 1  y  3
# 2  z  4

# %%
df2
# Out:
#    A  C
# 0  u  5
# 1  v  6
# 2  x  7

# %%
pd.merge(df1,df2,on='A')
# Out:
#    A  B  C
# 0  x  2  7

# %%
pd.merge(df1,df2,on='A',how='left')
# Out:
#    A  B    C
# 0  x  2  7.0
# 1  y  3  NaN
# 2  z  4  NaN

# %%
pd.merge(df1,df2,on='A',how='right')
# Out:
#    A    B  C
# 0  u  NaN  5
# 1  v  NaN  6
# 2  x  2.0  7

# %%
# pivoting

# %%
df = pd.read_csv("C:/Users/lalit/Downloads/P87-S7-Advanced-Manipulation-Resources/pres16results.csv")

# %%
df.head(2)
# Out:
#   county fips             cand  st  pct_report       votes  total_votes  \
# 0    NaN   US     Donald Trump  US      0.9951  60350241.0  127592176.0
# 1    NaN   US  Hillary Clinton  US      0.9951  60981118.0  127592176.0
#
#         pct          lead
# 0  0.472993  Donald Trump
# 1  0.477938  Donald Trump

# %%
# so here loc function came into picture if we want spcific column from a dataframe

# %%
top = df.loc[df.fips=='US',['cand','votes','total_votes']]

# %%
top.head()
# Out:
#               cand       votes  total_votes
# 0     Donald Trump  60350241.0  127592176.0
# 1  Hillary Clinton  60981118.0  127592176.0
# 2     Gary Johnson   4164589.0  127592176.0
# 3       Jill Stein   1255968.0  127592176.0
# 4    Evan McMullin    451636.0  127592176.0

# %%
#now if wanna work with only top 5 candidate

# %%
candidates=top.cand.head()

# %%
candidates
# Out:
# 0       Donald Trump
# 1    Hillary Clinton
# 2       Gary Johnson
# 3         Jill Stein
# 4      Evan McMullin
# Name: cand, dtype: object

# %%
df_candidate=df[df.cand.isin(candidates)]

# %%
df_candidate
# Out:
#               county   fips             cand  st  pct_report       votes  \
# 0                NaN     US     Donald Trump  US      0.9951  60350241.0
# 1                NaN     US  Hillary Clinton  US      0.9951  60981118.0
# 2                NaN     US     Gary Johnson  US      0.9951   4164589.0
# 3                NaN     US       Jill Stein  US      0.9951   1255968.0
# 4                NaN     US    Evan McMullin  US      0.9951    451636.0
# ...              ...    ...              ...  ..         ...         ...
# 18346    King County  48269       Jill Stein  TX      1.0000         0.0
# 18347  Loving County  48301     Donald Trump  TX      1.0000        57.0
# 18348  Loving County  48301  Hillary Clinton  TX      1.0000         4.0
# 18349  Loving County  48301       Jill Stein  TX      1.0000         2.0
# 18350  Loving County  48301     Gary Johnson  TX      1.0000         1.0
#
#        total_votes       pct          lead
# 0      127592176.0  0.472993  Donald Trump
# ...

# %% [markdown]
# #pivot

# %%
df_cand=df_candidate.pivot(index='fips',columns='cand',values='votes')

# %%
df_cand.head()
# Out:
# cand   Donald Trump  Evan McMullin  Gary Johnson  Hillary Clinton  Jill Stein
# fips
# 10001       36989.0            NaN        2876.0          33347.0      1041.0
# 10003       85507.0            NaN        9101.0         162905.0      3955.0
# 10005       62607.0            NaN        2774.0          39329.0      1104.0
# 1001        18110.0            NaN         538.0           5908.0       105.0
# 1003        72780.0            NaN        2448.0          18409.0       453.0

# %%
#pivot table

# %%
df.to_csv("C:/Users/lalit/Downloads/P87-S7-Advanced-Manipulation-Resources/happiness.csv",index=False,float_format='0.4f')

# %%
df.head()
# Out:
#        Country  Score  Year  GDP per capita
# 0  Switzerland  7.587  2015           1.397
# 1      Iceland  7.561  2015           1.302
# 2      Denmark  7.527  2015           1.325
# 3       Norway  7.522  2015           1.459
# 4       Canada  7.427  2015           1.326

# %%
df.pivot_table(index='Country',values='Score')
# Out:
#                Score
# Country
# Afghanistan  3.51280
# Albania      4.71260
# Algeria      5.66760
# Angola       3.87225
# Argentina    6.45940
# ...              ...
# Venezuela    5.53140
# Vietnam      5.15460
# Yemen        3.62580
# Zambia       4.58440
# Zimbabwe     4.00660
#
# [170 rows x 1 columns]

# %%
df.pivot_table(index='Country',values='Score',aggfunc=([np.mean,np.std,np.median]))
# Out:
#                 mean       std  median
#                Score     Score   Score
# Country
# Afghanistan  3.51280  0.232634  3.5750
# Albania      4.71260  0.145607  4.6550
# Algeria      5.66760  0.465170  5.6050
# Angola       3.87225  0.112272  3.8305
# Argentina    6.45940  0.231017  6.5740
# ...              ...       ...     ...
# Venezuela    5.53140  0.897944  5.2500
# Vietnam      5.15460  0.123009  5.1030
# Yemen        3.62580  0.294979  3.5930
# Zambia       4.58440  0.392690  4.5140
# Zimbabwe     4.00660  0.397866  3.8750
#
# [170 rows x 3 columns]

# %%
import numpy as np

# %%
df.pivot_table(index='Country',columns='Year')
# Out:
#             GDP per capita                              Score                \
# Year                  2015   2016   2017   2018   2019   2015   2016   2017
# Country
# Afghanistan          0.320  0.382  0.401  0.332  0.350  3.575  3.360  3.794
# Albania              0.879  0.955  0.996  0.916  0.947  4.959  4.655  4.644
# Algeria              0.939  1.053  1.092  0.979  1.002  5.605  6.355  5.872
# Angola               0.758  0.847  0.858  0.730    NaN  4.033  3.866  3.795
# Argentina            1.054  1.151  1.185  1.073  1.092  6.574  6.650  6.599
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# Venezuela            1.044  1.134  1.128  0.996  0.960  6.810  6.084  5.250
# Vietnam              0.632  0.740  0.789  0.715  0.741  5.360  5.061  5.074
# Yemen                0.546  0.579  0.592  0.442  0.287  4.077  3.724  3.593
# Zambia               0.470  0.612  0.636  0.562  0.578  5.129  4.795  4.514
# ...

# %%
# usoing swaplevel to

# %%
df.pivot_table(index="Country",columns='Year').swaplevel(0,1,axis=1).sort_index(axis=1,level=0)
# Out:
# Year                  2015                  2016                  2017         \
#             GDP per capita  Score GDP per capita  Score GDP per capita  Score
# Country
# Afghanistan          0.320  3.575          0.382  3.360          0.401  3.794
# Albania              0.879  4.959          0.955  4.655          0.996  4.644
# Algeria              0.939  5.605          1.053  6.355          1.092  5.872
# Angola               0.758  4.033          0.847  3.866          0.858  3.795
# Argentina            1.054  6.574          1.151  6.650          1.185  6.599
# ...                    ...    ...            ...    ...            ...    ...
# Venezuela            1.044  6.810          1.134  6.084          1.128  5.250
# Vietnam              0.632  5.360          0.740  5.061          0.789  5.074
# Yemen                0.546  4.077          0.579  3.724          0.592  3.593
# Zambia               0.470  5.129          0.612  4.795          0.636  4.514
# ...

# %%
# using margins in pivot table

# %%
df.pivot_table(index='Country',values='Score',columns='Year',margins=True,aggfunc=(np.sum),margins_name='sum_of_all')
# Out:
# Year            2015     2016     2017     2018     2019  sum_of_all
# Country
# Afghanistan    3.575    3.360    3.794    3.632    3.203      17.564
# Albania        4.959    4.655    4.644    4.586    4.719      23.563
# Algeria        5.605    6.355    5.872    5.295    5.211      28.338
# Angola         4.033    3.866    3.795    3.795      NaN      15.489
# Argentina      6.574    6.650    6.599    6.388    6.086      32.297
# ...              ...      ...      ...      ...      ...         ...
# Vietnam        5.360    5.061    5.074    5.103    5.175      25.773
# Yemen          4.077    3.724    3.593    3.355    3.380      18.129
# Zambia         5.129    4.795    4.514    4.377    4.107      22.922
# Zimbabwe       4.610    4.193    3.875    3.692    3.663      20.033
# sum_of_all   849.366  845.003  829.873  838.643  843.507    4206.392
#
# [171 rows x 6 columns]

# %%
# crosstab

# %%
df =pd.read_csv("C:/Users/lalit/Downloads/P87-S7-Advanced-Manipulation-Resources/heroes_information.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
pd.crosstab(index=df['Skin color'],columns=df['Eye color'])
# Out:
# Eye color         -  amber  black  blue  blue / white  bown  brown  gold  \
# Skin color
# -               167      2     18   212             1     1    125     2
# black             1      0      0     0             0     0      0     0
# blue              0      0      1     5             0     0      0     0
# blue-white        0      0      0     0             0     0      0     0
# gold              0      0      0     1             0     0      0     0
# gray              0      0      0     0             0     0      0     0
# green             1      0      1     2             0     0      1     0
# grey              1      0      0     0             0     0      0     0
# orange            0      0      0     0             0     0      0     0
# orange / white    0      0      0     0             0     0      0     0
# pink              0      0      0     0             0     0      0     0
# purple            0      0      0     1             0     0      0     0
# ...

# %%
# doing same thing using pivot_table

# %%
df.pivot_table(index='Skin color',columns='Eye color',values='Alignment',aggfunc='count',dropna=False,fill_value=0)
# Out:
# Eye color         -  amber  black  blue  blue / white  bown  brown  gold  \
# Skin color
# -               167      2     18   212             1     1    125     2
# black             1      0      0     0             0     0      0     0
# blue              0      0      1     5             0     0      0     0
# blue-white        0      0      0     0             0     0      0     0
# gold              0      0      0     1             0     0      0     0
# gray              0      0      0     0             0     0      0     0
# green             1      0      1     2             0     0      1     0
# grey              1      0      0     0             0     0      0     0
# orange            0      0      0     0             0     0      0     0
# orange / white    0      0      0     0             0     0      0     0
# pink              0      0      0     0             0     0      0     0
# purple            0      0      0     1             0     0      0     0
# ...

# %%
# margins act as a aggfunction(all) and normalize gives us data field in percentage format

# %%
pd.crosstab(index=df['Gender'],columns=df['Alignment'],margins=True,normalize='all')*100
# Out:
# Alignment         -        bad       good   neutral         All
# Gender
# -          0.136240   0.953678   2.588556  0.272480    3.950954
# Female     0.000000   4.768392  21.934605  0.544959   27.247956
# Male       0.817439  22.479564  43.051771  2.452316   68.801090
# All        0.953678  28.201635  67.574932  3.269755  100.000000

# %%
df
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %%
# spliting the string and set them into different column

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/lalit/Downloads/P87-Section-4-Basic-Data-Manipulations-Resources/P87-S4-Basic-Data-Manipulations-Resources/Section 4 - Extra Example Resources/cost-of-living.csv",index_col=0).T.reset_index()

# %%
df.head()
# Out:
#                       index  Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                          7.34
# 1          Istanbul, Turkey                          4.58
# 2             Izmir, Turkey                          3.06
# 3         Helsinki, Finland                         12.00
# 4         Chisinau, Moldova                          4.67
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                              65.00
# 4                                              20.74
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.40
# 1                                            3.82
# 2                                            3.06
# 3                                            8.00
# ...

# %%
df.rename(columns={'index':'Location'},inplace=True)

# %%
df[['city','country']]=df.Location.str.split(", ",expand=True,n=1)

# %%
df.head()
# Out:
#                    Location  Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                          7.34
# 1          Istanbul, Turkey                          4.58
# 2             Izmir, Turkey                          3.06
# 3         Helsinki, Finland                         12.00
# 4         Chisinau, Moldova                          4.67
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                              65.00
# 4                                              20.74
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.40
# 1                                            3.82
# 2                                            3.06
# 3                                            8.00
# ...
